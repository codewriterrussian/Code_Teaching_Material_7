# %% [markdown]
# 2026/08/09

# %%
print('hi') # 輸入資料 → 執行規則 → 輸出結果

# 輸入: 'hi'
# 執行: print
# 輸出: 'hi'

# def -> C => void -> return 0

# %%
# a = input()
input()

# 輸入: 使用者輸入
# 執行: 讀取輸入內容，找可以存取的地方
# 輸出: 存在記憶體

# %%
print(3, 2, 'abc', sep=',')

# %%
print(123, end='')
print(456)
# 123456\n

# %% [markdown]
# 請只使用下面三個文字：
#
# Python
# C
# C++
# 利用 sep 讓程式輸出：
#
# Python | C | C++

# %%
print('Python', 'C', 'C++', sep=' | ')

# %%
name, age, city = input('請輸入名字 年齡 城市：').split()  # 小明 13 台北
print(name)
# 小明|13|台北 -> 小明 13 台北

# %% [markdown]
# 讓使用者在同一行輸入：
#
# Apple Banana
# 將兩個資料分別存到 first 與 second，然後輸出：
#
# Apple
# Banana
# 你的程式：

# %%
first, second = input().split()

print(first, second, sep='\n')

# %% [markdown]
# 讓使用者在同一行輸入：
#
# 小明 台北
# 第一個資料是名字，第二個資料是城市。
#
# 程式最後要輸出：
#
# 姓名: 小明
# 城市: 台北

# %%
first, second = input().split()

# 有 4 個 print

print('姓名: ', end='')
print(first)
print('城市: ', end='')
print(second)

# %% [markdown]
# 範例輸入：
#
# 2026
# 06
# 07
# 預期輸出：
#
# 2026/06/07

# %%
one = input()
two = input()
three = input()

# print(one ,end='/')
# print(two ,end='/')
# print(three)

print(one, two, three, sep='/')

# %% [markdown]
# 範例輸入：
#
# A
# B
# C
# 預期輸出：
#
# ABC

# %%
one = input()
two = input()
three = input()
print(one, two, three, sep='')

# %% [markdown]
# 建立 age 變數，放入自己的年齡，並印出 age + 1。
# 建立 price = 45、count = "3"，把 count 轉成整數後計算總價。
# 建立一個串列 intro，放入姓名、年齡、是否喜歡 Python，並印出 intro。

# %%
age = int(input())
age = age + 1
print(age)

# %%
name = input()
age = int(input())
like_python = bool(input())

intro = [name, age, like_python]
print(intro)

# %% [markdown]
# 範例輸入：
#
# 4 7
# 範例輸出： (+/*)
#
# 11
# 28
# 請寫程式：

# %%
one, second = input().split()
one, second = int(one), int(second)

print(one + second)
print(one * second)
